# %%
# !pip install voila
# Out:
# Collecting voila
#   Downloading voila-0.5.8-py3-none-any.whl.metadata (9.5 kB)
# Collecting jupyter-client<9,>=7.4.4 (from voila)
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core>=4.11.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from voila) (4.11.1)
# Requirement already satisfied: jupyter-server<3,>=1.18 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from voila) (1.18.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from voila) (2.10.3)
# Requirement already satisfied: nbclient>=0.4.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from voila) (0.5.13)
# Collecting nbconvert<8,>=6.4.5 (from voila)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: traitlets<6,>=5.0.3 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from voila) (5.1.1)
# Collecting websockets>=9.0 (from voila)
#   Downloading websockets-15.0.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<9,>=7.4.4->voila) (4.11.3)
# Collecting jupyter-core>=4.11.0 (from voila)
#   Downloading jupyter_core-5.8.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<9,>=7.4.4->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<9,>=7.4.4->voila) (23.2.0)
# Collecting tornado>=6.2 (from jupyter-client<9,>=7.4.4->voila)
#   Downloading tornado-6.5.1-cp39-abi3-macosx_10_9_x86_64.whl.metadata (2.8 kB)
# Collecting traitlets<6,>=5.0.3 (from voila)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (3.5.0)
# Requirement already satisfied: argon2-cffi in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (21.3.0)
# Requirement already satisfied: jinja2 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (2.11.3)
# Requirement already satisfied: nbformat>=5.2.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (5.5.0)
# Requirement already satisfied: packaging in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (21.3)
# Requirement already satisfied: prometheus-client in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (0.14.1)
# Requirement already satisfied: Send2Trash in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (0.13.1)
# Requirement already satisfied: websocket-client in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server<3,>=1.18->voila) (0.58.0)
# Requirement already satisfied: idna>=2.8 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.18->voila) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.18->voila) (1.2.0)
# Requirement already satisfied: babel in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.9.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.4)
# Requirement already satisfied: json5 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.16.0)
# Requirement already satisfied: requests in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila) (4.11.1)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Collecting jinja2 (from jupyter-server<3,>=1.18->voila)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jupyterlab-pygments in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila) (2.0.1)
# Collecting mistune<4,>=2.0.3 (from nbconvert<8,>=6.4.5->voila)
#   Downloading mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbformat>=5.2.0 (from jupyter-server<3,>=1.18->voila)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila) (2.18.0)
# Requirement already satisfied: typing-extensions in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from mistune<4,>=2.0.3->nbconvert<8,>=6.4.5->voila) (4.12.2)
# Requirement already satisfied: six>=1.9.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.16.0)
# Requirement already satisfied: webencodings in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# WARNING: bleach 4.1.0 does not provide the extra 'css'
# Requirement already satisfied: zipp>=0.5 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client<9,>=7.4.4->voila) (3.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from jupyter-core>=4.11.0->voila) (2.5.2)
# Requirement already satisfied: nest-asyncio in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbclient>=0.4.0->voila) (1.5.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.18->voila) (2.16.2)
# Requirement already satisfied: ptyprocess in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from terminado>=0.8.3->jupyter-server<3,>=1.18->voila) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=1.18->voila) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.18->voila) (1.15.1)
# Requirement already satisfied: pycparser in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.18->voila) (2.21)
# Requirement already satisfied: pytz>=2015.7 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from babel->jupyterlab-server<3,>=2.3.0->voila) (2022.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from packaging->jupyter-server<3,>=1.18->voila) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyterlab-server<3,>=2.3.0->voila) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyterlab-server<3,>=2.3.0->voila) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Daniella/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyterlab-server<3,>=2.3.0->voila) (2022.9.24)
# Downloading voila-0.5.8-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 7.2 MB/s eta 0:00:0000:0100:01
# Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading jupyter_core-5.8.1-py3-none-any.whl (28 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading tornado-6.5.1-cp39-abi3-macosx_10_9_x86_64.whl (440 kB)
# Downloading websockets-15.0.1-cp39-cp39-macosx_10_9_x86_64.whl (173 kB)
# Installing collected packages: websockets, traitlets, tornado, mistune, jinja2, jupyter-core, nbformat, jupyter-client, nbconvert, voila
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: tornado━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [traitlets]
#     Found existing installation: tornado 6.1━━━━━━━━━━━━━━━━━━  1/10 [traitlets]
#     Uninstalling tornado-6.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [traitlets]
#       Successfully uninstalled tornado-6.1━━━━━━━━━━━━━━━━━━━━  1/10 [traitlets]
#   Attempting uninstall: mistune━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [tornado]
#     Found existing installation: mistune 0.8.4━━━━━━━━━━━━━━━━  2/10 [tornado]
#     Uninstalling mistune-0.8.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [tornado]
#       Successfully uninstalled mistune-0.8.4━━━━━━━━━━━━━━━━━━━━━━  3/10 [mistune]
#   Attempting uninstall: jinja2━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [mistune]
#     Found existing installation: Jinja2 2.11.3━━━━━━━━━━━━━━━━  3/10 [mistune]
#     Uninstalling Jinja2-2.11.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [mistune]
#       Successfully uninstalled Jinja2-2.11.3━━━━━━━━━━━━━━━━━━  3/10 [mistune]
#   Attempting uninstall: jupyter-core0m━━━━━━━━━━━━━━━━━━━━━━━  4/10 [jinja2]
#     Found existing installation: jupyter_core 4.11.1━━━━━━━━━━  4/10 [jinja2]
#     Uninstalling jupyter_core-4.11.1:0m━━━━━━━━━━━━━━━━━━━━━━━  4/10 [jinja2]
#       Successfully uninstalled jupyter_core-4.11.1━━━━━━━━━━━━━━━━  5/10 [jupyter-core]
#   Attempting uninstall: nbformat╺━━━━━━━━━━━━━━━━━━━  5/10 [jupyter-core]
#     Found existing installation: nbformat 5.5.0━━━━━━━━━━━━━━━  5/10 [jupyter-core]
#     Uninstalling nbformat-5.5.0:m╺━━━━━━━━━━━━━━━━━━━  5/10 [jupyter-core]
#       Successfully uninstalled nbformat-5.5.0━━━━━━━━━━━━━━━━━  5/10 [jupyter-core]
#   Attempting uninstall: jupyter-client━━━━━━━━━━━━━━━━━━━  5/10 [jupyter-core]
#     Found existing installation: jupyter_client 7.3.4━━━━━━━━━  5/10 [jupyter-core]
#     Uninstalling jupyter_client-7.3.4:0m╺━━━━━━━━━━━  7/10 [jupyter-client]
#       Successfully uninstalled jupyter_client-7.3.4━━━━━━━━━━━  7/10 [jupyter-client]
#   Attempting uninstall: nbconvert╺━━━━━━━━━━━  7/10 [jupyter-client]
#     Found existing installation: nbconvert 6.4.490m━━━━━━━━━━━  7/10 [jupyter-client]
#     Uninstalling nbconvert-6.4.4:━━━━━━━╺━━━━━━━  8/10 [nbconvert]]
#       Successfully uninstalled nbconvert-6.4.4━━━━━━━  8/10 [nbconvert]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [voila]m 9/10 [voila]ert]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.3.3 requires pyqt5<5.16, which is not installed.
# spyder 5.3.3 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.10.4 which is incompatible.
# distributed 2022.7.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.5.1 which is incompatible.
# spyder-kernels 2.3.3 requires jupyter-client<8,>=7.3.4; python_version >= "3", but you have jupyter-client 8.6.3 which is incompatible.
# Successfully installed jinja2-3.1.6 jupyter-client-8.6.3 jupyter-core-5.8.1 mistune-3.1.3 nbconvert-7.16.6 nbformat-5.10.4 tornado-6.5.1 traitlets-5.14.3 voila-0.5.8 websockets-15.0.1

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
from datetime import date
import base64
from datetime import date

# %%
# Required imports
import os
import base64
from datetime import date
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# Setup styling
def get_base64_image(image_path):
    with open(image_path, 'rb') as f:
        image_bytes = f.read()
    encoded = base64.b64encode(image_bytes).decode('utf-8')
    return f"<img src='data:image/jpeg;base64,{encoded}' width='120'>"

display(HTML("""
<style>
    .container { width:100% !important; }
    .widget-button { background-color: #004080 !important; color: white; border-radius: 5px; }
    .main-box { padding: 20px; background-color: #fafafa; border-left: 1px solid #ccc; }
    .sidebar-box { background-color: #f0f0f0; padding: 20px; border-right: 2px solid #ccc; height: 100%; }
    .footer { text-align: center; color: #888; margin-top: 40px; font-size: 13px; }
</style>
"""))

# Globals
experiment_data = []
archived_data = []
main_output = widgets.Output()

# Helper for limited text area
def make_limited_textarea(default_val):
    textarea = widgets.Textarea(
        value=default_val,
        layout=widgets.Layout(width="100%", height="80px"),
        placeholder="150–200 characters"
    )
    counter = widgets.Label(f"{len(textarea.value)} / 200")

    def on_text_change(change):
        val = change['new']
        if len(val) > 200:
            textarea.value = val[:200]
        counter.value = f"{len(textarea.value)} / 200"

    textarea.observe(on_text_change, names='value')
    return widgets.VBox([textarea, counter])

# File widget logic
def create_file_widgets(folder):
    widgets_list = []
    if not os.path.exists(folder):
        return widgets.HTML("<i>No uploaded files.</i>")

    for fname in os.listdir(folder):
        fpath = os.path.join(folder, fname)
        file_buttons = []

        view_button = widgets.Button(description=f"View: {fname}", button_style='info')
        def on_view_click(b, p=fpath):
            with main_output:
                clear_output()
                if p.endswith('.csv'):
                    with open(p, 'r') as f:
                        data = f.read()
                    display(widgets.HTML(f"<pre>{data}</pre>"))
                elif p.endswith('.pdf'):
                    display(widgets.HTML(f"<iframe src='{p}' width='100%' height='500px'></iframe>"))
                else:
                    display(widgets.HTML(f"<p>Cannot preview: {p}</p>"))
        view_button.on_click(on_view_click)
        file_buttons.append(view_button)

        if fname.endswith('.csv'):
            stats_button = widgets.Button(description="Search Stats", button_style='warning')
            stats_button.on_click(lambda b: print("work in progress"))
            file_buttons.append(stats_button)

        delete_button = widgets.Button(description="Delete", button_style='danger')
        def on_delete_click(b, p=fpath):
            os.remove(p)
            with main_output:
                clear_output()
                display(widgets.HTML(f"Deleted {p}"))
        delete_button.on_click(on_delete_click)
        file_buttons.append(delete_button)

        widgets_list.append(widgets.HBox(file_buttons))
    return widgets.VBox(widgets_list)

# Show experiment form
def show_add_experiment_form():
    with main_output:
        clear_output()

        title = widgets.Text(placeholder="Title (required)")
        owner = widgets.Text(placeholder="Owner")
        start_date = widgets.DatePicker(value=date.today())
        end_date = widgets.DatePicker()
        hypothesis = make_limited_textarea('')
        materials = make_limited_textarea('')
        observations = make_limited_textarea('')
        conclusions = make_limited_textarea('')

        upload = widgets.FileUpload(accept='', multiple=True)
        upload_output = widgets.Output()

        def on_upload_change(change):
            if not title.value:
                upload_output.clear_output()
                with upload_output:
                    print("Please enter a title before uploading files.")
                return

            folder = os.path.join("uploads", title.value.replace(" ", "_"))
            os.makedirs(folder, exist_ok=True)
            for filename, fileinfo in upload.value.items():
                with open(os.path.join(folder, filename), "wb") as f:
                    f.write(fileinfo['content'])
            upload_output.clear_output()
            with upload_output:
                display(create_file_widgets(folder))

        upload.observe(on_upload_change, names='value')

        submit_btn = widgets.Button(description="Save Entry", button_style='success')
        def on_submit(b):
            folder = os.path.join("uploads", title.value.replace(" ", "_"))
            experiment_data.append({
                'title': title.value,
                'owner': owner.value,
                'start_date': start_date.value,
                'end_date': end_date.value,
                'hypothesis': hypothesis.children[0].value,
                'materials': materials.children[0].value,
                'observations': observations.children[0].value,
                'conclusions': conclusions.children[0].value,
                'folder': folder
            })
            clear_output()
            display(widgets.HTML(f"<h3>Saved Experiment: {title.value}</h3>"))

        display(widgets.VBox([
            widgets.HTML("<h2>New Experiment</h2>"),
            title, owner, widgets.HBox([start_date, end_date]),
            widgets.Label("Hypothesis"), hypothesis,
            widgets.Label("Materials"), materials,
            widgets.Label("Observations"), observations,
            widgets.Label("Upload Files"), upload, upload_output,
            widgets.Label("Conclusions"), conclusions,
            submit_btn
        ]))

# Layout UI
logo_html = widgets.HTML(get_base64_image("20_15_visioneers_logo.jpg"))
add_exp_btn = widgets.Button(description="Add Experiment", layout=widgets.Layout(width='100%'))
add_exp_btn.on_click(lambda b: show_add_experiment_form())

sidebar = widgets.VBox([
    widgets.HTML("<h2>Prototype ELN</h2>"),
    widgets.Label(f"Date: {date.today()}"),
    widgets.HTML("<hr>"),
    add_exp_btn,
    logo_html,
    widgets.HTML("<div class='footer'>20/15 Visioneers<br>ELN demo</div>")
], layout=widgets.Layout(
    min_width='280px', max_width='320px', border='solid 1px lightgray',
    padding='10px', height='100vh', overflow='auto'
))

app_layout = widgets.HBox([
    sidebar,
    widgets.VBox([main_output], layout=widgets.Layout(padding='20px', width='75%', overflow='auto'))
], layout=widgets.Layout(width='100%', height='100vh', border='solid 1px #ddd'))

display(app_layout)
with main_output:
    clear_output()
    print("hello")
    display(widgets.HTML("<h2>Welcome to your ELN</h2><p>Click on the left to start.</p>"))
# Out:
# <style>
#     .container { width:100% !important; }
#     .widget-button { background-color: #004080 !important; color: white; border-radius: 5px; }
#     .main-box { padding: 20px; background-color: #fafafa; border-left: 1px solid #ccc; }
#     .sidebar-box { background-color: #f0f0f0; padding: 20px; border-right: 2px solid #ccc; height: 100%; }
#     .footer { text-align: center; color: #888; margin-top: 40px; font-size: 13px; }
# </style>
# HBox(children=(VBox(children=(HTML(value='<h2>Prototype ELN</h2>'), Label(value='Date: 2025-06-11'), HTML(valu…
